# %%
import cv2
import matplotlib.pyplot as plt
from tqdm import tnrange, tqdm_notebook
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-76-a7a4d93deb04> in <module>()
#       1 import cv2
#       2 import matplotlib.pyplot as plt
# ----> 3 from tqdm import tnrange, tqdm_notebook
#
# ImportError: No module named tqdm

# %%
cap = cv2.VideoCapture('bohemian_rhapsody_live_aid.mp4')

# %%
(major_ver, minor_ver, subminor_ver) = (cv2.__version__).split('.')
print((major_ver, minor_ver, subminor_ver) )
# Out:
# ('4', '1', '1')

# %%
total_frames = vidcap.get(7)

# %%
total_frames
# Out:
# 10885.0

# %%
fps = cap.get(cv2.CAP_PROP_FPS)
print(fps)
# Out:
# 59.9400599401

# %%
total_frames/60
# Out:
# 181.41666666666666

# %%
cap.set(1, 600)
ret, frame = cap.read()
plt.axis('off')
plt.imshow(frame)
plt.show()

# %%
frames_to_analyze = []
w = 60
jump = 120
for i in range(w + 1, int(total_frames), 2*w):
    cap.set(1, i)
    _, frame = cap.read()
    
    cap.set(1, i - 2*w)
    ret, past_frame = cap.read()
    
    frames_to_analyze.append([past_frame, frame])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-75-fd5c9ceb7798> in <module>()
#       6     _, frame = cap.read()
#       7
# ----> 8     cap.set(1, i - 2*w)
#       9     ret, past_frame = cap.read()
#      10
#
# KeyboardInterrupt:

# %%
frames_to_analyze
# Out:
# 91
